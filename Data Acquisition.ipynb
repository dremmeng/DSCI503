# %%
import requests
import pandas as pd
import json
res = requests.get("https://api.nasa.gov/neo/rest/v1/neo/3542519?api_key=DEMO_KEY")
data=res.json()
df=pd.json_normalize(data)
df.to_csv("Nasa Data.csv")
df.info()
df.describe()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 43 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   id                                                    1 non-null      object
#  1   neo_reference_id                                      1 non-null      object
#  2   name                                                  1 non-null      object
#  3   designation                                           1 non-null      object
#  4   nasa_jpl_url                                          1 non-null      object
#  5   absolute_magnitude_h                                  1 non-null      float64
#  6   is_potentially_hazardous_asteroid                     1 non-null      bool
#  7   close_approach_data                                   1 non-null      object
# ...
